# %%
import pandas as pd 
import numpy as np

# %%
CB_201307="C:\\Users\\mstas\\Desktop\\Tableau\\Resources\\2013-07 - Citi Bike trip data.csv"

CB_201407="C:\\Users\\mstas\\Desktop\\Tableau\\Resources\\2014-07 - Citi Bike trip data.csv"

# %%
CB_201307_df = pd.read_csv(CB_201307)

CB_201407_df = pd.read_csv(CB_201407)

# %%
combined_1314 = pd.concat([ CB_201307_df, CB_201407_df])
combined_1314.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           634  2013-07-01 00:00:00  2013-07-01 00:10:34               164
# 1          1547  2013-07-01 00:00:02  2013-07-01 00:25:49               388
# 2           178  2013-07-01 00:01:04  2013-07-01 00:04:02               293
# 3          1580  2013-07-01 00:01:06  2013-07-01 00:27:26               531
# 4           757  2013-07-01 00:01:10  2013-07-01 00:13:47               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
# ...

# %%
list(combined_1314)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
len(combined_1314)
# Out:
# 1812258

# %%
combined_1314.rename(columns={'tripduration':'Duration', 'starttime':'Start_Time', 'stoptime':'Stop_Time', 'start station id':'Start_Station_Id', 'start station name':'Start_Station', 'bikeid':'Bike Id', 'birthyear':'Birth Year', 'gender':'Gender'}, inplace = True )

# %%
combined_1314.dropna()
# Out:
#         Duration           Start_Time            Stop_Time  Start_Station_Id  \
# 0            634  2013-07-01 00:00:00  2013-07-01 00:10:34               164
# 1           1547  2013-07-01 00:00:02  2013-07-01 00:25:49               388
# 2            178  2013-07-01 00:01:04  2013-07-01 00:04:02               293
# 3           1580  2013-07-01 00:01:06  2013-07-01 00:27:26               531
# 4            757  2013-07-01 00:01:10  2013-07-01 00:13:47               382
# ...          ...                  ...                  ...               ...
# 968837      2136  2014-07-31 23:59:44  2014-08-01 00:35:20               150
# 968838       260  2014-07-31 23:59:46  2014-08-01 00:04:06               450
# 968839       318  2014-07-31 23:59:47  2014-08-01 00:05:05               521
# 968840       299  2014-07-31 23:59:50  2014-08-01 00:04:49               229
# 968841       511  2014-07-31 23:59:58  2014-08-01 00:08:29               282
#
# ...

# %%
combined_1314.drop(combined_1314.index[combined_1314['birth year'] == 0], inplace=True)
combined_1314.head()
# Out:
#    Duration           Start_Time            Stop_Time  Start_Station_Id  \
# 0       634  2013-07-01 00:00:00  2013-07-01 00:10:34               164
# 1      1547  2013-07-01 00:00:02  2013-07-01 00:25:49               388
# 2       178  2013-07-01 00:01:04  2013-07-01 00:04:02               293
# 3      1580  2013-07-01 00:01:06  2013-07-01 00:27:26               531
# 4       757  2013-07-01 00:01:10  2013-07-01 00:13:47               382
#
#              Start_Station  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  \
# ...

# %%
#trying again to drop the "/N" in the Birth year column 
combined_1314.dropna(subset=['birth year'] , inplace = True)
combined_1314.head()
# Out:
#    Duration           Start_Time            Stop_Time  Start_Station_Id  \
# 0       634  2013-07-01 00:00:00  2013-07-01 00:10:34               164
# 1      1547  2013-07-01 00:00:02  2013-07-01 00:25:49               388
# 2       178  2013-07-01 00:01:04  2013-07-01 00:04:02               293
# 3      1580  2013-07-01 00:01:06  2013-07-01 00:27:26               531
# 4       757  2013-07-01 00:01:10  2013-07-01 00:13:47               382
#
#              Start_Station  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station id         end station name  end station latitude  \
# ...

# %%
len(combined_1314)
# Out:
# 1812258

# %%
indexNames = combined_1314[combined_1314['birth year'] == '1899'].index
 
combined_1314.drop(indexNames , inplace=True)

# %%
combined_1314.drop(combined_1314.loc[combined_1314['birth year']==1900].index, inplace=True)

# %%
len(combined_1314.index)
# Out:
# 1812021

# %%
combined_1314.dtypes
# Out:
# Duration                     int64
# Start_Time                  object
# Stop_Time                   object
# Start_Station_Id             int64
# Start_Station               object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# Bike Id                      int64
# usertype                    object
# birth year                  object
# Gender                       int64
# dtype: object

# %%
combined_1314.loc[combined_1314["Gender"] == "1","Gender"] = Male
combined_1314.loc[combined_1314["Gender"] == "2","Gender"] = Female
combined_1314.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7864/3668737395.py in <module>
# ----> 1 combined_1314.loc[combined_1314["Gender"] == "1","Gender"] = Male
#       2 combined_1314.loc[combined_1314["Gender"] == "2","Gender"] = Female
#       3 combined_1314.head()
#
# NameError: name 'Male' is not defined

# %%
Main_df=combined_1314.filter(['Duration', 'Start_Time','Start_Time',"Start_Station_Id", "Start_Station","start station latitude", "start station longitude", "end station id ", " end station name", "end station latitude", "end station longitude", "usertype", "Gender"], axis=1)

# %%
Main_df.head()
# Out:
#    Duration           Start_Time           Start_Time  Start_Station_Id  \
# 0       634  2013-07-01 00:00:00  2013-07-01 00:00:00               164
# 1      1547  2013-07-01 00:00:02  2013-07-01 00:00:02               388
# 2       178  2013-07-01 00:01:04  2013-07-01 00:01:04               293
# 3      1580  2013-07-01 00:01:06  2013-07-01 00:01:06               531
# 4       757  2013-07-01 00:01:10  2013-07-01 00:01:10               382
#
#              Start_Station  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
#    end station latitude  end station longitude    usertype  Gender
# ...

# %%
len(Main_df)
# Out:
# 1812021

# %%
combined_1314.to_csv('C:\\Users\\mstas\\Desktop\\Tableau\\Main_df.csv', index = False)
